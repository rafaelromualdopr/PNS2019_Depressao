# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Out:
# C:\Users\rafae\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("Bases/base_sem_outliers.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'C006', 'M01401', 'M01501', 'E01602', 'VDF001', 'E017',
#        'D00901', 'Q092', 'A001', 'A002010', 'A003010', 'A004010', 'J007',
#        'Q11006', 'N00101', 'P034', 'P027', 'J01101', 'J014', 'N010', 'N011',
#        'N012', 'N013', 'N014', 'N015', 'N016', 'N017', 'N018', 'J001',
#        'J00101', 'J002', 'P006', 'P00901', 'P01101', 'P013', 'P015', 'P02001',
#        'P01601', 'P018', 'P02002', 'P023', 'P02501', 'P02602', 'P02601',
#        'E001', 'P050', 'IMC'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Supondo que 'data' é seu DataFrame e 'P00104' é a coluna com os dados
# data = pd.read_csv('seu_arquivo.csv') # Carregar o DataFrame

# Definir estilo dos gráficos
sns.set_style("whitegrid")

# Criar figura para o gráfico
fig, ax = plt.subplots(figsize=(10, 6))

# Histograma para 'data_zscore' com colunas mais grossas
sns.histplot(df['E01602'], ax=ax, kde=True)
ax.set_title('Distribuição do Peso (Com Outliers)')
ax.set_xlabel('Peso')

# Mostrar o gráfico
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
